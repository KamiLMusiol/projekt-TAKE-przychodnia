# %%
from testowanie.testowanie_wyswietlanie_json import show_as_json, GeneratorDanych


gen = GeneratorDanych()

specjalizacje = gen.generuj_dane_specjalizacja()
choroby = gen.generuj_dane_choroby()
pacjenci = gen.generuj_dane_pacjent(3)
lekarze = gen.generuj_dane_lekarz(2)
wizyty = gen.generuj_dane_wizyta(2, max_lekarz_id=2, max_pacjent_id=3)

# %% [markdown]
# Testowanie specjalizacji

# %%
show_as_json("Specjalizacje", specjalizacje)
# Out:
# ==================== SPECJALIZACJE ====================
# [
#     {
#         "nazwa_specjalizacji": "Kardiologia",
#         "opis": "Diagnostyka i leczenie chorób układu krążenia."
#     },
#     {
#         "nazwa_specjalizacji": "Neurologia",
#         "opis": "Diagnostyka i leczenie chorób układu nerwowego."
#     },
#     {
#         "nazwa_specjalizacji": "Pediatria",
#         "opis": "Profilaktyka i leczenie chorób dziecięcych."
#     },
#     {
#         "nazwa_specjalizacji": "Ortopedia",
#         "opis": "Leczenie urazów i schorzeń narządu ruchu."
#     },
#     {
#         "nazwa_specjalizacji": "Rodzinny",
#         "opis": "Wszystko inne."
#     }
# ]

# %% [markdown]
# Testowanie chorób

# %%
show_as_json("Choroby", choroby)
# Out:
# ==================== CHOROBY ====================
# [
#     {
#         "nazwa": "Nadciśnienie tętnicze",
#         "opis": "Trwałe podwyższenie ciśnienia krwi powyżej 140/90 mmHg prowadzące do uszkodzeń naczyń."
#     },
#     {
#         "nazwa": "Cukrzyca typu 2",
#         "opis": "Zaburzenie metaboliczne cechujące się opornością na insulinę i wysokim poziomem glukozy."
#     },
#     {
#         "nazwa": "Grypa sezonowa",
#         "opis": "Ostra choroba zakaźna układu oddechowego wywołana przez wirusy grypy typu A lub B."
#     },
#     {
#         "nazwa": "Astma oskrzelowa",
#         "opis": "Przewlekłe zapalenie dróg oddechowych objawiające się napadami duszności i kaszlu."
#     },
#     {
#         "nazwa": "Choroba wieńcowa",
#         "opis": "Niedokrwienie serca spowodowane zwężeniem tętnic wieńcowych przez blaszki miażdżycowe."
#     },
#     {
#         "nazwa": "Niedoczynność tarczycy",
# ...

# %% [markdown]
# Testowanie pacjentów

# %%
show_as_json("Pacjenci", pacjenci)
# Out:
# ==================== PACJENCI ====================
# [
#     {
#         "imie": "Julian",
#         "nazwisko": "Rychert",
#         "pesel": "93072487242",
#         "dataUrodzenia": "1952-02-20",
#         "numerTelefonu": "724 436 464",
#         "adres": "ul. Wyszyńskiego 70, 08-207 Swarzędz"
#     },
#     {
#         "imie": "Maksymilian",
#         "nazwisko": "Jasica",
#         "pesel": "22051138154",
#         "dataUrodzenia": "1950-10-11",
#         "numerTelefonu": "+48 691 874 134",
#         "adres": "pl. Orzechowa 47, 92-791 Dąbrowa Górnicza"
#     },
#     {
#         "imie": "Tola",
#         "nazwisko": "Piersa",
#         "pesel": "95050256235",
#         "dataUrodzenia": "1986-09-04",
#         "numerTelefonu": "22 883 77 85",
#         "adres": "aleja Widokowa 25, 89-915 Zawiercie"
#     }
# ]

# %% [markdown]
# Testowanie lekarzy

# %%
show_as_json("Lekarze", lekarze)
# Out:
# ==================== LEKARZE ====================
# [
#     {
#         "imie": "Ryszard",
#         "nazwisko": "Manista",
#         "numerPwz": "8270682",
#         "email": "marcelgradek@example.net",
#         "specjalizacje": [
#             {
#                 "id": 3
#             },
#             {
#                 "id": 1
#             }
#         ]
#     },
#     {
#         "imie": "Dariusz",
#         "nazwisko": "Michniak",
#         "numerPwz": "7621224",
#         "email": "ftylus@example.net",
#         "specjalizacje": [
#             {
#                 "id": 5
#             }
#         ]
#     }
# ]

# %% [markdown]
# Testowanie wizyt

# %%
show_as_json("Wizyty", wizyty)
# Out:
# ==================== WIZYTY ====================
# [
#     {
#         "dataWizyty": "2026-03-18",
#         "zalecenia": "coś tam coś tam daj 100 zł masz lizaka widzimy się za dwa lata",
#         "lekarz": {
#             "id": 1
#         },
#         "pacjent": {
#             "id": 1
#         },
#         "choroby": [
#             {
#                 "id": 21
#             },
#             {
#                 "id": 18
#             },
#             {
#                 "id": 27
#             }
#         ]
#     },
#     {
#         "dataWizyty": "2025-12-10",
#         "zalecenia": "coś tam coś tam daj 100 zł masz lizaka widzimy się za dwa lata",
#         "lekarz": {
#             "id": 2
#         },
#         "pacjent": {
#             "id": 1
#         },
#         "choroby": [
#             {
#                 "id": 11
#             }
#         ]
#     }
# ]
